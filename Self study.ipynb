# %%
readMe = open('Meterstanden.csv','r').readlines()
print(len(readMe))
readMe[:5]
# Out:
# 39
# ['Opmerking,maand/dag/jaar,maand,jaar,stand_water,stand_gas,stand_electriciteit,# dagen,# maand,# water mÂ³,# gas mÂ³,# electriciteit kWh,Gemiddelde/mnd,water,gas,electriciteit,,,,,,,,Aantal dagen,Totaal per periode,water,gas,electriciteit\n',
#  'Start (chauffage aan-uit),5/13/2016,5,2016,3652.28,23111.241,111706.6,,,,,,,,,,,,,,,,,#REF!,#REF!,#REF!,#REF!,#REF!\n',
#  ',5/25/2016,5,2016,3654,23121.142,111737.4,,0.4,,#REF!,,0.4,4,25,77,,,,,,,,#REF!,#REF!,#REF!,#REF!,#REF!\n',
#  ',5/30/2016,5,2016,3654.6327,23125.212,111752.9,,,,#VALUE!,,,,,,,,,,,,,#REF!,#REF!,#REF!,#REF!,#REF!\n',
#  'Chauffage AAN,06/01/2016,6,2016,3654,23127.19,111761.6,19,0.6,2.7,25.2,86.8,0.6,2.7,25.2,86.8,,,,,,,,0,0.0,0,0,0\n']

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/tinep/Downloads/Meterstanden.csv")
#df.columns
#print(df.head(5))
df.set_index("maand/dag/jaar", inplace='True')
#print(df.head(5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-58533f7c9066> in <module>()
#       2 #df.columns
#       3 #print(df.head(5))
# ----> 4 df.set_index("maand/dag/jaar", inplace='True')
#       5 #print(df.head(5))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3865         dataframe : DataFrame
#    3866         """
# -> 3867         inplace = validate_bool_kwarg(inplace, 'inplace')
#    3868         if not isinstance(keys, list):
#    3869             keys = [keys]
#
# ~\Anaconda3\lib\site-packages\pandas\util\_validators.py in validate_bool_kwarg(value, arg_name)
#     224         raise ValueError('For argument "{arg}" expected type bool, received '
#     225                          'type {typ}.'.format(arg=arg_name,
# ...

# %%
ls # all content working directory
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 622C-60F4
#
#  Directory of C:\Users\tinep\Downloads
#
#
#  Directory of C:\Users\tinep\Downloads
#
#
#  Directory of C:\Users\tinep\Downloads
#
#
#  Directory of C:\Users\tinep\Downloads
#
#
#  Directory of C:\Users\tinep\Downloads
# File Not Found

# %%
df = pd.read_csv("C:/Users/tinep/Downloads/80-cereals/cereal.csv")
df.head(5)
#print(df)
# column 'fat' is loaded as 'object', because one value is 'no info'
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    .     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4  NaN     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df2 = pd.read_csv("80-cereals/cereal.csv")
df2.head(5)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
# Are they the same?
print(pd.DataFrame.equals(cereal_df, cereal_df2))
# Out:
# True

# %%
dfSkip = pd.read_csv("80-cereals/cereal.csv", skiprows = 2)
print(dfSkip.head(5))
# Out:
#            100% Natural Bran  Q  C  120  3  5   15     2     8  8.1  135   0  \
# 0                   All-Bran  K  C   70  4  1  260   9.0   7.0    5  320  25
# 1  All-Bran with Extra Fiber  K  C   50  4  0  140  14.0   8.0    0  330  25
# 2             Almond Delight  R  C  110  2  2  200   1.0  14.0    8   -1  25
# 3    Apple Cinnamon Cheerios  G  C  110  2  2  180   1.5  10.5   10   70  25
# 4                Apple Jacks  K  C  110  2  0  125   1.0  11.0   14   30  25
#
#    3.1    1   1.1  33.983679
# 0    3  1.0  0.33  59.425505
# 1    3  1.0  0.50  93.704912
# 2    3  1.0  0.75  34.384843
# 3    1  1.0  0.75  29.509541
# 4    2  1.0  1.00  33.174094

# %%
# what is the datatype
print(df['mfr'].dtypes)
print(df['calories'].dtypes)
print(df['fat'].dtypes)
# Out:
# object
# int64
# object

# %%
print(df['fat'][0] + df['fat'][1])
# Out:
# 15

# %%
# to prevent datatype 'object' because of value 'no info'
df = pd.read_csv("80-cereals/cereal.csv", 
                 #skiprows = 1, 
                 na_values = ['no info', '.'])
print(df.head(5))
print(df['fat'].dtypes)
print(df['fat'][0] + df['fat'][1])
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4  1.0     130   10.0
# 1          100% Natural Bran   Q    C       120        3  5.0      15    2.0
# 2                   All-Bran   K    C        70        4  NaN     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4  NaN     140   14.0
# 4             Almond Delight   R    C       110        2  2.0     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843
# float64
# 6.0

# %%
# How many rows the dataset
df['name'].count()

# Use of min & max with a condition
df['calories'][df['name'] == '100% Bran'].min()
#df['calories'].max()
# Out:
# 70

# %%
# Use of min & max with a condition: string like...
df['calories'][df['name'].str.contains("Bran")].min()
#df[df['name'].str.contains("Bran")]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4  1.0     130   10.0
# 1           100% Natural Bran   Q    C       120        3  5.0      15    2.0
# 2                    All-Bran   K    C        70        4  NaN     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4  NaN     140   14.0
# 8                   Bran Chex   R    C        90        2  1.0     200    4.0
# 9                 Bran Flakes   P    C        90        3  0.0     210    5.0
# 19         Cracklin' Oat Bran   K    C       110        3  3.0     140    4.0
# 28              Fruitful Bran   K    C       120        3  0.0     240    5.0
# 52      Post Nat. Raisin Bran   P    C       120        3  1.0     200    6.0
# 58                Raisin Bran   K    C       120        3  1.0     210    5.0
# 59            Raisin Nut Bran   G    C       100        3  2.0     140    2.5
# ...

# %%
df['name'].str.contains("Bran")
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
#       ...
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52     True
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58     True
# 59     True
# 60    False
# 61    False
# 62    False
# 63    False
# 64     True
# 65    False
# 66    False
# 67    False
# 68    False
# 69    False
# 70     True
# 71    False
# 72    False
# 73    False
# 74    False
# 75    False
# 76    False
# Name: name, Length: 77, dtype: bool

# %%
# freq tabel 
df['mfr'].value_counts()
# Out:
# K    23
# G    22
# P     9
# R     8
# Q     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %%
# aantal unieke values
df['name'].nunique() # aantal unieke
df['name'].count() # totaal aantal
# Out:
# 77

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  75.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.026667  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.013068   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
### .groupby() -- Aggregatie met groepering

# %%
df.groupby(['mfr']).groups.keys()
# Out:
# dict_keys(['A', 'G', 'K', 'N', 'P', 'Q', 'R'])

# %%
df.groupby('mfr')['calories'].min()
# Out:
# mfr
# A    100
# G    100
# K     50
# N     70
# P     90
# Q     50
# R     90
# Name: calories, dtype: int64

# %%
df[df['name'].str.contains('Bran')].groupby('mfr')['calories'].sum()
# Out:
# mfr
# G    240
# K    470
# N    160
# P    210
# Q    120
# R     90
# Name: calories, dtype: int64

# %%
df.groupby('mfr')['calories'].sum()
# Out:
# mfr
# A     100
# G    2450
# K    2500
# N     520
# P     980
# Q     760
# R     920
# Name: calories, dtype: int64

# %%
df.groupby(['type', 'mfr']).count()
# Out:
#           name  calories  protein  fat  sodium  fiber  carbo  sugars  potass  \
# type mfr
# C    G      22        22       22   22      22     22     22      22      22
#      K      23        23       23   21      23     23     23      23      23
#      N       5         5        5    5       5      5      5       5       5
#      P       9         9        9    9       9      9      9       9       9
#      Q       7         7        7    7       7      7      7       7       7
#      R       8         8        8    8       8      8      8       8       8
# H    A       1         1        1    1       1      1      1       1       1
#      N       1         1        1    1       1      1      1       1       1
#      Q       1         1        1    1       1      1      1       1       1
#
#           vitamins  shelf  weight  cups  rating
# type mfr
# C    G          22     22      22    22      22
#      K          23     23      23    23      23
# ...
